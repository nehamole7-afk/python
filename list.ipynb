# %%
mark=[25,12,26,37]
print(mark[0])
# Out:
# 25

# %%
mark=[25,12,26,37]
mark.append(40)
print(mark)
# Out:
# [25, 12, 26, 37, 40]

# %%
num={1,2,2,3,3,4}
print(num)
# Out:
# {1, 2, 3, 4}

# %%
student={"name":"neha","age":21,"marks":90}
(student["name"])
# Out:
#   File "C:\Users\CCF\AppData\Local\Temp/ipykernel_8348/1915502487.py", line 1
#     student={"name:"neha","age":21,"marks":90}
#                     ^
# SyntaxError: invalid syntax

# %%
name="python"
print(name[0])
print(name[-1])
# Out:
# p
# n
