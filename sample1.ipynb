# %%
a=int(input("enter a number1:"))
b=int(input("enter a number2:"))
c=a+b
print(c)
# Out:
# enter a number1:5
# enter a number2:5
# 10

# %%
name=input("enter a name:")
age=int(input("enter your age:"))
mark=int(input("enter your mark:"))
print(name)
print(age)
print(mark)
# Out:
# enter a name:Neha
# enter your age:21
# enter your mark:78
# Neha
# 21
# 78

# %%
age=21
name="Neha"
mark=78.5
passed=True
print(type(age))
print(type(mark))
print(type(name))
print(type(passed))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a=int(input("enter the side of a square:"))
area=a*a
print(area)
# Out:
# enter the side of a square:4
# 16

# %%
b=int(input("enter the base of the right-angled triangle"))
h=int(input("enter the height of the right-angled triangle"))
area=0.5*b*h
print(area)
# Out:
# enter the base of the right-angled triangle4
# enter the height of the right-angled triangle4
# 8.0

# %%
p=int(input("enter the principal amount:"))
n=int(input("enter the number of years:"))
r=int(input("enter the rate of interest:"))
si=p*n*r/100
print(si)
# Out:
# enter the principal amount:50000
# enter the number of years:5
# enter the rate of interest:20
# 50000.0

# %%
a=int(input("enter a number:"))
print(a)
print("nxt number=",a+1)
print("previous number=",a-1)
# Out:
# enter a number:10
# 10
# nxt number= 11
# previous number= 9
