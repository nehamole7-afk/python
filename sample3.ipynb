# %%
n=int(input("enter a number:"))
if(n>0):
    print("the number is postive")
elif n<0:
     print("the number is negative")
else:
    print("c is biggest")
# Out:
# enter a number:8
# the number is postive

# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
c=int(input("enter the third number:"))
if a>b and a>c:
        print("a is greater")
elif b>a and b>c:
       print("b is greater")
else:
     print("c is greater")
# Out:
# enter the first number:9
# enter the second number:2
# enter the third number:1
# a is greater

# %%
a=int(input("enter a age:"))
if a<13:
    print("Child")
elif a<20:
     print("Teenager")
else:
    print("adult")
# Out:
# enter a age:18
# Teenager

# %%
num=int(input("enter the number(1-7):"))
if num==1:
    print("Sunday")
elif num==2:
    print("Monday")
elif num==3:
    print("Tuesday")
elif num==4:
    print("Wednesday")
elif num==5:
    print("Thuesday")
elif num==6:
    print("Friday")
elif num==7:
    print("Saturday")
else:
    print("Unvalid")
# Out:
# enter the number(1-7):6
# Friday

# %%
num=int(input("enter the number(1-12):"))
if num==1:
    print("Jan")
elif num==2:
    print("feb")
elif num==3:
    print("Mar")
elif num==4:
    print("April")
elif num==5:
    print("May")
elif num==6:
    print("Jun")
elif num==7:
    print("JUL")
elif num==8:
    print("Aug")
elif num==9:
    print("Sep")
elif num==10:
    print("Oct")
elif num==11:
    print("Nov")
elif num==12:
    print("Dec")
else:
    print("Unvalid")
# Out:
# enter the number(1-12):9
# Sep

# %%
num=int(input("enter the number:"))
if n%7==0:
    print("the number is divisible by 7")
else:
    print("the number is not dividible by 7")
# Out:
# enter the number:14
# the number is not dividible by 7

# %%
n=input("enter the character:")
if n in ("a,e,i,o,u,A,E,I,O,U"):
    print("vowels")
else:
    print("not vowels")
# Out:
# enter the character:e
# vowels

# %%
age=int(input("enter the age:"))
if age>=18:
    print("Eligible to apply for a driving license")
else:
    print("Not eligible")
# Out:
# enter the age:13
# Not eligible

# %%
a=(input("enter the a string:"))
b=(input("enter the second string:"))
if a==b:
        print("it is equall")
else:
     print("Not equall")
# Out:
# enter the a string:f
# enter the second string:r
# Not equall

# %%
amt=int(input("enter the amount:"))
if(amt>5000):
        print("Eligible for discount")
else:
     print("not eligible")
# Out:
# enter the amount:2000
# not eligible

# %%
n=int(input("enter the number:"))
if(n>=10 and n<=100):
    print("the number is between 10 and 100")
else:
    print("not between 10 and 100")
# Out:
# enter the number:20
# the number is between 10 and 100

# %%
n=float(input("enter the attendance percentage:"))
if n>75:
    print("eligible to attend the exam")
else:
    print("not eligible")
# Out:
# enter the attendance percentage:55
# not eligible

# %%
n=(input("enter the alphabet:"))
if n.isupper():
    print("alphabet is in uppercase")
elif n.islower():
    print("alphabet is in lowercase")
else:
    print("none")
# Out:
# enter the alphabet:D
# alphabet is in uppercase

# %%
n=int(input("enter the number:"))
if n>=100 and n<=999:
    print("the number is 3 digits")
else:
    print("not 3 digits")
# Out:
# enter the number:55
# not 3 digits

# %%
data=float(input("enter amount of moblie data in gb:"))
if data<2:
    print("low usage")
elif data<=5:
    print("moderate usage")
else:
    print("high usage")
# Out:
# enter amount of moblie data in gb:5
# moderate usage
